# %% [markdown]
# <a href="https://colab.research.google.com/github/mia-netizen/bigdata/blob/main/%E6%9C%9F%E6%9C%AB%E5%B0%88%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("ls",TRUE)
# Out:
# [1] "sample_data"

# %%
system("ls",TRUE)
# Out:
# [1] "sample_data"  "懸浮微粒.csv"

# %%
library(readr)

# %%
dataset <- read.csv("懸浮微粒.csv")

# %%
dataset
# Out:
#    SiteName   County AQI Pollutant  Status SO2 CO   CO_8hr O3   O3_8hr ⋯ NO
# 1  基隆       基隆市 36             良好   1.0 0.21 0.2         39     ⋯  1.4
# 2  汐止       新北市 44             良好   1.8 0.29 0.3    23.5 37     ⋯  2.8
# 3  萬里       新北市 41             良好   2.0 0.21 0.2    31.6 44     ⋯  1.5
# 4  新店       新北市 37             良好   1.5 0.32 0.3    27   40     ⋯  2.8
# 5  土城       新北市 59  細懸浮微粒 普通   2.0 0.33 0.4    26.2 47     ⋯  2.5
# 6  板橋       新北市 54  細懸浮微粒 普通   2.3 0.41 0.4    16.7 38     ⋯  7.1
# 7  新莊       新北市 61  細懸浮微粒 普通   2.3 0.42 0.4    26   43     ⋯  3.7
# 8  菜寮       新北市 60  細懸浮微粒 普通   1.3 0.37 0.4    25.8 41     ⋯  4.0
# 9  林口       新北市 63  細懸浮微粒 普通   2.1 0.24 0.3    41.3 44     ⋯  2.6
# 10 淡水       新北市 48             良好   1.2 0.22 0.2    35.2 45     ⋯  1.1
# 11 士林       臺北市 52  細懸浮微粒 普通    NA      0.2         48     ⋯   NA
# 12 中山       臺北市 59  細懸浮微粒 普通   1.9 0.53 0.5    17.5 36     ⋯  9.3
# 13 萬華       臺北市 53  細懸浮微粒 普通    NA      0.4    23.5 42     ⋯   NA
# ...

# %%
dataset[grepl("臺南市",dataset$County),]
# Out:
#    SiteName   County AQI Pollutant  Status SO2 CO   CO_8hr O3   O3_8hr ⋯ NO
# 43 新營       臺南市 59  細懸浮微粒 普通   1.1 0.19 0.3    47.4 45     ⋯ 1.4
# 44 善化       臺南市 45             良好   1.2 0.18 0.2    38.7 42     ⋯ 1.3
# 45 安南       臺南市 47             良好   1.3 0.18 0.2    43.8 45     ⋯ 0.9
# 46 臺南       臺南市 51  細懸浮微粒 普通   1.4 0.25 0.3    41   45     ⋯ 0.8
# 79 臺南(麻豆) 臺南市 57  細懸浮微粒 普通   1.1 0.19 0.2    41.1 39     ⋯ 0.9
# 83 臺南(學甲) 臺南市 57  細懸浮微粒 普通   0.5 0.2  0.2    33.5 34     ⋯ 4.8
#    WindSpeed WindDirec PublishTime         PM2.5_AVG PM10_AVG SO2_AVG Longitude
# 43 2.4       338       2021/04/27 16:00:00 19        41       1       120.3173
# 44 1.6       302       2021/04/27 16:00:00 14        25       2       120.2971
# 45 3.2       308       2021/04/27 16:00:00 14        33       1       120.2175
# 46 2.5       344       2021/04/27 16:00:00 16        32       2       120.2026
# 79 2         2         2021/04/27 16:00:00 18        31       1       120.2458
# ...
